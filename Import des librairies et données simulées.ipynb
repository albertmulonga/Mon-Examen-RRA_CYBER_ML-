# %%
# Librairies
import pandas as pd
import numpy as np
import time
from IPython.display import display, clear_output
from sklearn.ensemble import RandomForestRegressor

# %%
# Pour NLP simple
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Pour NLP simple
# ----> 2 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# Simulation LLM (juste un exemple)
def llm_advice(montant, heure):
    if montant > 10000:
        return "⚠️ Montant élevé, vérifiez la conformité fiscale."
    elif heure < 8 or heure > 18:
        return "⏰ Transaction hors heures ouvrables, soyez vigilant."
    else:
        return "✅ Transaction normale."

# %%
# Exemple de dataset simulé pour Random Forest
np.random.seed(42)
df = pd.DataFrame({
    "montant": np.random.randint(100, 20000, 100),
    "heure": np.random.randint(0, 24, 100),
    "risque": np.random.randint(0, 2, 100)  # 0 = faible, 1 = élevé
})

# %%
# Modèle Random Forest
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(df[["montant", "heure"]], df["risque"])
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# ### Import des librairies et données simulées

# %%
# Splash animé
clear_output()
splash_text = """
==========================================
   RRA ML – APPLICATION FISCALE
   Créée par : INGENIEUR ALBERT MULONGA
   Le Gourou en Informatique
   Fonctionnalité : Prédiction et Analyse
==========================================
"""

for c in splash_text:
    print(c, end="", flush=True)
    time.sleep(0.01)  # animation du texte

print("\n\nChargement de l'application...")
time.sleep(3)
clear_output()

# %% [markdown]
# ### Formulaire de transaction

# %%
# Formulaire
print("\n--- FORMULAIRE DE TRANSACTION ---")
montant = float(input("💰 Montant de la transaction : "))
heure = int(input("⏰ Heure de la transaction (0-23) : "))
description = input("📝 Description de la transaction : ")
# Out:
# --- FORMULAIRE DE TRANSACTION ---

# %% [markdown]
# ### Prédictions des 3 modèles

# %% [markdown]
# # Random Forest
# rf_prediction = rf_model.predict([[montant, heure]])[0]
# rf_prediction_text = "Risque élevé ⚠️" if rf_prediction > 0.5 else "Risque faible ✅"
#
# # NLP
# text_blob = TextBlob(description)
# nlp_sentiment = text_blob.sentiment.polarity
# nlp_text = "🔴 Attention : sentiment négatif détecté" if nlp_sentiment < 0 else "🟢 Sentiment positif ou neutre"
#
# # LLM
# llm_text = llm_advice(montat, heure)

# %% [markdown]
# ### Affichage des résultats avec design simple

# %%
print("\n==========================================")
print("          RÉSULTATS DE LA PREDICTION")
print("==========================================\n")

print(f"1️⃣ Random Forest : {rf_prediction_text}")
print(f"2️⃣ NLP Analyse : {nlp_text}")
print(f"3️⃣ LLM Conseil : {llm_text}")

print("\nMerci d'utiliser l'application RRA ML !")

# %% [markdown]
# ### Exportation du modèle

# %%
import pickle
with open('Prédiction et Analyse','wb') as model_file:
    pickle.dump(linearReg,model_file)
